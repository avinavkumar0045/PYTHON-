# %%
# !pip install langchain langchain-core langchain-community pypdf pymupdf sentence-transformers chromadb
# Out:
# Requirement already satisfied: langchain in /Applications/anaconda3/lib/python3.13/site-packages (1.3.16)
# Requirement already satisfied: langchain-core in /Applications/anaconda3/lib/python3.13/site-packages (1.6.0)
# Requirement already satisfied: langchain-community in /Applications/anaconda3/lib/python3.13/site-packages (0.4.2)
# Requirement already satisfied: pypdf in /Applications/anaconda3/lib/python3.13/site-packages (6.16.2)
# Requirement already satisfied: pymupdf in /Applications/anaconda3/lib/python3.13/site-packages (1.28.2)
# Requirement already satisfied: sentence-transformers in /Applications/anaconda3/lib/python3.13/site-packages (6.0.0)
# Requirement already satisfied: chromadb in /Applications/anaconda3/lib/python3.13/site-packages (1.5.9)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain) (2.12.4)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core) (0.11.1)
# Requirement already satisfied: packaging>=23.2.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core) (0.17.0)
# Requirement already satisfied: anyio in /Applications/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (4.10.0)
# Requirement already satisfied: certifi in /Applications/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Applications/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (1.0.9)
# Requirement already satisfied: idna in /Applications/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (3.18)
# Requirement already satisfied: h11>=0.16 in /Applications/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Applications/anaconda3/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /Applications/anaconda3/lib/python3.13/site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.3)
# Requirement already satisfied: xxhash>=3.5.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /Applications/anaconda3/lib/python3.13/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.12.0)
# Requirement already satisfied: websockets<17,>=14 in /Applications/anaconda3/lib/python3.13/site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (16.1.1)
# Requirement already satisfied: distro>=1.7.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Applications/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Applications/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Applications/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: numpy>=2.1.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-community) (2.3.5)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-community) (2.0.43)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Applications/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Applications/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Applications/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Applications/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Applications/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Applications/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Applications/anaconda3/lib/python3.13/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Applications/anaconda3/lib/python3.13/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Applications/anaconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Applications/anaconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.5.0)
# Requirement already satisfied: transformers<6.0.0,>=5.0.0 in /Applications/anaconda3/lib/python3.13/site-packages (from sentence-transformers) (5.15.0)
# Requirement already satisfied: tokenizers>=0.19 in /Applications/anaconda3/lib/python3.13/site-packages (from sentence-transformers) (0.22.2)
# Requirement already satisfied: huggingface-hub<2.0.0,>=1.3.0 in /Applications/anaconda3/lib/python3.13/site-packages (from sentence-transformers) (1.27.0)
# Requirement already satisfied: torch>=2.2 in /Applications/anaconda3/lib/python3.13/site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /Applications/anaconda3/lib/python3.13/site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy>=1.0.0 in /Applications/anaconda3/lib/python3.13/site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: tqdm>=4.0.0 in /Applications/anaconda3/lib/python3.13/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /Applications/anaconda3/lib/python3.13/site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /Applications/anaconda3/lib/python3.13/site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Applications/anaconda3/lib/python3.13/site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /Applications/anaconda3/lib/python3.13/site-packages (from huggingface-hub<2.0.0,>=1.3.0->sentence-transformers) (1.6.0)
# Requirement already satisfied: regex>=2025.10.22 in /Applications/anaconda3/lib/python3.13/site-packages (from transformers<6.0.0,>=5.0.0->sentence-transformers) (2026.7.19)
# Requirement already satisfied: typer in /Applications/anaconda3/lib/python3.13/site-packages (from transformers<6.0.0,>=5.0.0->sentence-transformers) (0.17.4)
# Requirement already satisfied: safetensors>=0.8.0 in /Applications/anaconda3/lib/python3.13/site-packages (from transformers<6.0.0,>=5.0.0->sentence-transformers) (0.8.0)
# Requirement already satisfied: build>=1.0.3 in /Applications/anaconda3/lib/python3.13/site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pybase64>=1.4.1 in /Applications/anaconda3/lib/python3.13/site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: uvicorn>=0.18.3 in /Applications/anaconda3/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.52.1)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Applications/anaconda3/lib/python3.13/site-packages (from chromadb) (1.29.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Applications/anaconda3/lib/python3.13/site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Applications/anaconda3/lib/python3.13/site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Applications/anaconda3/lib/python3.13/site-packages (from chromadb) (1.44.0)
# Requirement already satisfied: pypika>=0.48.9 in /Applications/anaconda3/lib/python3.13/site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: overrides>=7.3.1 in /Applications/anaconda3/lib/python3.13/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /Applications/anaconda3/lib/python3.13/site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in /Applications/anaconda3/lib/python3.13/site-packages (from chromadb) (1.83.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Applications/anaconda3/lib/python3.13/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /Applications/anaconda3/lib/python3.13/site-packages (from chromadb) (36.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in /Applications/anaconda3/lib/python3.13/site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in /Applications/anaconda3/lib/python3.13/site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /Applications/anaconda3/lib/python3.13/site-packages (from chromadb) (4.25.0)
# Requirement already satisfied: pyproject_hooks in /Applications/anaconda3/lib/python3.13/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Applications/anaconda3/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Applications/anaconda3/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Applications/anaconda3/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.28.0)
# Requirement already satisfied: six>=1.9.0 in /Applications/anaconda3/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Applications/anaconda3/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Applications/anaconda3/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Applications/anaconda3/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /Applications/anaconda3/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in /Applications/anaconda3/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in /Applications/anaconda3/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (7.36.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Applications/anaconda3/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.44.0 in /Applications/anaconda3/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-proto==1.44.0 in /Applications/anaconda3/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.44.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.65b0 in /Applications/anaconda3/lib/python3.13/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.65b0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Applications/anaconda3/lib/python3.13/site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Applications/anaconda3/lib/python3.13/site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Applications/anaconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: joblib>=1.2.0 in /Applications/anaconda3/lib/python3.13/site-packages (from scikit-learn>=1.1.0->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Applications/anaconda3/lib/python3.13/site-packages (from scikit-learn>=1.1.0->sentence-transformers) (3.5.0)
# Requirement already satisfied: setuptools in /Applications/anaconda3/lib/python3.13/site-packages (from torch>=2.2->sentence-transformers) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Applications/anaconda3/lib/python3.13/site-packages (from torch>=2.2->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Applications/anaconda3/lib/python3.13/site-packages (from torch>=2.2->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /Applications/anaconda3/lib/python3.13/site-packages (from torch>=2.2->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Applications/anaconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch>=2.2->sentence-transformers) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /Applications/anaconda3/lib/python3.13/site-packages (from typer->transformers<6.0.0,>=5.0.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: httptools>=0.8.0 in /Applications/anaconda3/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Requirement already satisfied: uvloop>=0.15.1 in /Applications/anaconda3/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /Applications/anaconda3/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Applications/anaconda3/lib/python3.13/site-packages (from jinja2->torch>=2.2->sentence-transformers) (3.0.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /Applications/anaconda3/lib/python3.13/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)

# %%
from langchain_core.documents import Document

# %%
sample_doc = Document(  # defining a doc 
    page_content="Hello World!",
    metadata={"source":"https://www.google.com"} 
)

# %%
sample_doc
# Out:
# Document(metadata={'source': 'https://www.google.com'}, page_content='Hello World!')

# %%
type(sample_doc)
# Out:
# langchain_core.documents.base.Document

# %%
# Text data
from langchain_community.document_loaders.text import TextLoader

loader = TextLoader("data/Python.txt", encoding="utf-8")

# %%
document = loader.load()

# %% [markdown]
# document # loaded the pdf

# %%
# # PDF data
# from langchain_community.document_loaders.pdf import PyPDFLoader # pyMuPDFLoader for complex pdfs

# pdf_loader = PyPDFLoader("data/research2.pdf")

# document = pdf_loader.load()
# document

# %% [markdown]
# # INGESTION MODULE

# %%
# Data => module
import os
from langchain_community.document_loaders.pdf import PyPDFLoader

# %% [markdown]
# ## Documents

# %%
def load_all_pdfs():
    folder_path = "data/pdfs"
    num_docs = 0
    all_docs = []

    for filename in os.listdir(folder_path):
        if filename.lower().endswith(".pdf"):
            pdf_path = os.path.join(folder_path, filename)

            loader = PyPDFLoader(pdf_path)
            doc = loader.load()

            all_docs.extend(doc)
            num_docs += 1

    print("total pdfs :", num_docs)
    print("total pages :", len(all_docs))

    return all_docs

# %%
all_pdf_documents  = load_all_pdfs()
# Out:
# total pdfs : 2
# total pages : 32

# %%
type(all_pdf_documents[1])
# Out:
# langchain_core.documents.base.Document

# %% [markdown]
# # CHUNKS

# %%
# !pip install langchain_text_splitters
# Out:
# Requirement already satisfied: langchain_text_splitters in /Applications/anaconda3/lib/python3.13/site-packages (1.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain_text_splitters) (1.6.0)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.11.1)
# Requirement already satisfied: packaging>=23.2.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.17.0)
# Requirement already satisfied: anyio in /Applications/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (4.10.0)
# Requirement already satisfied: certifi in /Applications/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Applications/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.0.9)
# Requirement already satisfied: idna in /Applications/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (3.18)
# Requirement already satisfied: h11>=0.16 in /Applications/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Applications/anaconda3/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (3.0.0)
# Requirement already satisfied: distro>=1.7.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.3.0)
# Requirement already satisfied: websockets>=15.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Applications/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Applications/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Applications/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Applications/anaconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Applications/anaconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2.5.0)

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

def split_docs(documents , chunk_size = 500 , chunk_overlap = 50):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size = chunk_size,
        chunk_overlap = chunk_overlap
    )

    chunked_docs = text_splitter.split_documents(documents)
    return chunked_docs

# %%
chunks = split_docs(all_pdf_documents)

# %%
len(chunks)
# Out:
# 320

# %%
#chunks

# %% [markdown]
#  ## Embedding

# %%
from sentence_transformers import SentenceTransformer

# %%
class EmbeddingManager:
    def __init__(self, model_name="all-MiniLM-L6-v2"):

        self.model_name = model_name
        print("loading model....", self.model_name)
        self.model = SentenceTransformer(self.model_name)
        print(
            "embedding dimensions=",
            self.model.get_sentence_embedding_dimension(),
        )

    def generate_embeddings(self, text):
        embeddings = self.model.encode(text, show_progress_bar=True)
        print("embeddings shape:", embeddings.shape)
        return embeddings

# %%
embedding_manager = EmbeddingManager()
# Out:
# loading model.... all-MiniLM-L6-v2
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# embedding dimensions= 384
# /var/folders/1c/29w4nj612ns_rgx1ljtbvlnh0000gn/T/ipykernel_2526/4268907676.py:9: FutureWarning: The `get_sentence_embedding_dimension` method has been renamed to `get_embedding_dimension`.
#   self.model.get_sentence_embedding_dimension(),

# %% [markdown]
# # Vector Store

# %%
# vector store manager
# 1. initialize vector store manager
# 2. vs initialize -> path , collection
# 3. store all the documents in the Vector store

# %%
import chromadb
import uuid # help us create indexes for our value

# %%
class VectorStoreManager:
    def __init__(self, persist_directory="data/vector_store", collection_name="pdf_documents"):
        self.collection_name = collection_name
        self.persist_directory = persist_directory
        self.collection = None
        self.client = None

        self._initialize_store()

    def _initialize_store(self):
        os.makedirs(self.persist_directory, exist_ok=True)
        
        # create a client
        self.client = chromadb.PersistentClient(path=self.persist_directory)

        # create the collection
        self.collection = self.client.get_or_create_collection(
            name=self.collection_name,
            metadata={"description": "vector store collection for pdf embeddings in RAG"}
        )

        print("initialized the vector store with collection:", self.collection_name)
        print("docs in collection:", self.collection.count())

    def add_documents(self, documents, embeddings):
        if len(documents) != len(embeddings):
            raise ValueError("num of documents does not match num of embeddings")


        # store => ids, embedding, document, metadata
        ids = []
        all_metadata = []
        documents_content = []
        embeddings_list = []

        for i, (doc, embedding) in enumerate(zip(documents, embeddings)):
            doc_id = f"doc_{uuid.uuid4()}"
            ids.append(doc_id)

            metadata = dict(doc.metadata)
            metadata["doc_index"] = i
            metadata["content_length"] = len(doc.page_content)
            all_metadata.append(metadata)

            documents_content.append(doc.page_content)

            embeddings_list.append(embedding.tolist())

            self.collection.add(
                ids=ids,
                metadatas=all_metadata,
                documents=documents_content,
                embeddings=embeddings_list
            )

        print("total documents added in vector store=", len(documents_content))
        print("docs in collection:", self.collection.count())

# %%
vector_store = VectorStoreManager()
# Out:
# initialized the vector store with collection: pdf_documents
# docs in collection: 493

# %%
# data => documents => chunks => embeddings => store in vector store
# now we are going to create embeddings form cunks

texts = [doc.page_content for doc in chunks]

emebedding = embedding_manager.generate_embeddings(texts)

vector_store.add_documents(chunks, emebedding)
# Out:
# Batches:   0%|          | 0/10 [00:00<?, ?it/s]
# embeddings shape: (320, 384)
# total documents added in vector store= 320
# docs in collection: 813

# %% [markdown]
# # Retrieval  Pipeline

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
class RAGRetriever:
    def __init__(self, embedding_manager, vector_store):
        self.embedding_manager = embedding_manager
        self.vector_store = vector_store


    def retrieve(self, query, top_k=5, score_threshold=0.0):
        # query => embedding
        query_embeddings = self.embedding_manager.generate_embeddings([query])[0]

        # semantic search
        results = self.vector_store.collection.query(
            query_embeddings=[query_embeddings.tolist()],
            n_results=top_k
        )

        # cosine similarity
        retrieved_docs=[]
        
        if results["documents"] and results["documents"][0]:
            ids = results["ids"][0]
            metadatas = results["metadatas"][0]
            documents = results["documents"][0]
            distances = results["distances"][0]

            for i, (doc_id, metadata, document, distance) in enumerate(zip(ids, metadatas, documents, distances)):
                similarity_score = 1 - distance

                if similarity_score >= score_threshold:
                    retrieved_docs.append({
                        "id": doc_id,
                        "document": document,
                        "metadata": metadata,
                        "distance": distance,
                        "similarity_score": similarity_score,
                        "rank" : i + 1
                    })

            print(f"retrieved {len(retrieved_docs)} documents")

        else:
            print("no documents found")

        return retrieved_docs

# %%
rag_retriever = RAGRetriever(embedding_manager, vector_store)

# %%
rag_retriever.retrieve("What is encoder decoder")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# embeddings shape: (1, 384)
# retrieved 4 documents
# [{'id': 'doc_dc92f73a-d653-459d-99a7-f19629a2ca4b',
#   'document': 'positional encodings in both the encoder and decoder stacks. For the base model, we use a rate of\nPdrop = 0.1.\n7',
#   'metadata': {'published': '2017',
#    'lastpage': '6008',
#    'author': 'Ashish Vaswani, Noam Shazeer, Niki Parmar, Jakob Uszkoreit, Llion Jones, Aidan N. Gomez, Łukasz Kaiser, Illia Polosukhin',
#    'source': 'data/pdfs/research1.pdf',
#    'eventtype': 'Poster',
#    'producer': 'PyPDF2',
#    'book': 'Advances in Neural Information Processing Systems 30',
#    'page': 6,
#    'publisher': 'Curran Associates, Inc.',
#    'total_pages': 11,
#    'editors': 'I. Guyon and U.V. Luxburg and S. Bengio and H. Wallach and R. Fergus and S. Vishwanathan and R. Garnett',
#    'doc_index': 293,
#    'moddate': '2018-02-12T21:22:10-08:00',
#    'type': 'Conference Proceedings',
#    'creator': 'PyPDF',
#    'creationdate': '',
#    'created': '2017',
#    'language': 'en-US',
#    'title': 'Attention is All you Need',
#    'firstpage': '5998',
#    'date': '2017',
#    'description-abstract': 'The dominant sequence transduction models are based on complex recurrent orconvolutional neural networks in an encoder and decoder configuration. The best performing such models also connect the encoder and decoder through an attentionm echanisms.  We propose a novel, simple network architecture based solely onan attention mechanism, dispensing with recurrence and convolutions entirely.Experiments on two machine translation tasks show these models to be superiorin quality while being more parallelizable and requiring significantly less timeto train. Our single model with 165 million parameters, achieves 27.5 BLEU onEnglish-to-German translation, improving over the existing best ensemble result by over 1 BLEU. On English-to-French translation, we outperform the previoussingle state-of-the-art with model by 0.7 BLEU, achieving a BLEU score of 41.1.',
#    'description': 'Paper accepted and presented at the Neural Information Processing Systems Conference (http://nips.cc/)',
#    'content_length': 112,
#    'subject': 'Neural Information Processing Systems http://nips.cc/',
#    'page_label': '7'},
#   'distance': 0.7821964621543884,
#   'similarity_score': 0.21780353784561157,
#   'rank': 1},
#  {'id': 'doc_d4a20f9a-e068-4b01-abd1-892af5f140d7',
#   'document': 'layers, produce outputs of dimensiondmodel = 512.\nDecoder: The decoder is also composed of a stack ofN = 6 identical layers. In addition to the two\nsub-layers in each encoder layer, the decoder inserts a third sub-layer, which performs multi-head\nattention over the output of the encoder stack. Similar to the encoder, we employ residual connections\naround each of the sub-layers, followed by layer normalization. We also modify the self-attention',
#   'metadata': {'creationdate': '',
#    'subject': 'Neural Information Processing Systems http://nips.cc/',
#    'lastpage': '6008',
#    'description': 'Paper accepted and presented at the Neural Information Processing Systems Conference (http://nips.cc/)',
#    'created': '2017',
#    'author': 'Ashish Vaswani, Noam Shazeer, Niki Parmar, Jakob Uszkoreit, Llion Jones, Aidan N. Gomez, Łukasz Kaiser, Illia Polosukhin',
#    'date': '2017',
#    'type': 'Conference Proceedings',
#    'page_label': '3',
#    'producer': 'PyPDF2',
#    'firstpage': '5998',
#    'description-abstract': 'The dominant sequence transduction models are based on complex recurrent orconvolutional neural networks in an encoder and decoder configuration. The best performing such models also connect the encoder and decoder through an attentionm echanisms.  We propose a novel, simple network architecture based solely onan attention mechanism, dispensing with recurrence and convolutions entirely.Experiments on two machine translation tasks show these models to be superiorin quality while being more parallelizable and requiring significantly less timeto train. Our single model with 165 million parameters, achieves 27.5 BLEU onEnglish-to-German translation, improving over the existing best ensemble result by over 1 BLEU. On English-to-French translation, we outperform the previoussingle state-of-the-art with model by 0.7 BLEU, achieving a BLEU score of 41.1.',
#    'creator': 'PyPDF',
#    'eventtype': 'Poster',
#    'source': 'data/pdfs/research1.pdf',
#    'title': 'Attention is All you Need',
#    'content_length': 447,
#    'page': 2,
#    'editors': 'I. Guyon and U.V. Luxburg and S. Bengio and H. Wallach and R. Fergus and S. Vishwanathan and R. Garnett',
#    'total_pages': 11,
#    'doc_index': 262,
#    'moddate': '2018-02-12T21:22:10-08:00',
#    'publisher': 'Curran Associates, Inc.',
#    'language': 'en-US',
#    'book': 'Advances in Neural Information Processing Systems 30',
#    'published': '2017'},
#   'distance': 0.7845929265022278,
#   'similarity_score': 0.21540707349777222,
#   'rank': 2},
#  {'id': 'doc_c8682396-244b-426a-b895-1d9d98e0d2f8',
#   'document': 'respectively.\n3.1 Encoder and Decoder Stacks\nEncoder: The encoder is composed of a stack of N = 6 identical layers. Each layer has two\nsub-layers. The ﬁrst is a multi-head self-attention mechanism, and the second is a simple, position-\n2',
#   'metadata': {'publisher': 'Curran Associates, Inc.',
#    'published': '2017',
#    'author': 'Ashish Vaswani, Noam Shazeer, Niki Parmar, Jakob Uszkoreit, Llion Jones, Aidan N. Gomez, Łukasz Kaiser, Illia Polosukhin',
#    'subject': 'Neural Information Processing Systems http://nips.cc/',
#    'editors': 'I. Guyon and U.V. Luxburg and S. Bengio and H. Wallach and R. Fergus and S. Vishwanathan and R. Garnett',
#    'eventtype': 'Poster',
#    'title': 'Attention is All you Need',
#    'doc_index': 260,
#    'total_pages': 11,
#    'language': 'en-US',
#    'moddate': '2018-02-12T21:22:10-08:00',
#    'page': 1,
#    'description-abstract': 'The dominant sequence transduction models are based on complex recurrent orconvolutional neural networks in an encoder and decoder configuration. The best performing such models also connect the encoder and decoder through an attentionm echanisms.  We propose a novel, simple network architecture based solely onan attention mechanism, dispensing with recurrence and convolutions entirely.Experiments on two machine translation tasks show these models to be superiorin quality while being more parallelizable and requiring significantly less timeto train. Our single model with 165 million parameters, achieves 27.5 BLEU onEnglish-to-German translation, improving over the existing best ensemble result by over 1 BLEU. On English-to-French translation, we outperform the previoussingle state-of-the-art with model by 0.7 BLEU, achieving a BLEU score of 41.1.',
#    'source': 'data/pdfs/research1.pdf',
#    'page_label': '2',
#    'book': 'Advances in Neural Information Processing Systems 30',
#    'lastpage': '6008',
#    'created': '2017',
#    'creationdate': '',
#    'creator': 'PyPDF',
#    'firstpage': '5998',
#    'type': 'Conference Proceedings',
#    'content_length': 237,
#    'producer': 'PyPDF2',
#    'date': '2017',
#    'description': 'Paper accepted and presented at the Neural Information Processing Systems Conference (http://nips.cc/)'},
#   'distance': 0.8704500198364258,
#   'similarity_score': 0.12954998016357422,
#   'rank': 3},
#  {'id': 'doc_679dd35e-4b6e-4d8a-8fbb-025c1f55e917',
#   'document': '[31, 2, 8].\n• The encoder contains self-attention layers. In a self-attention layer all of the keys, values\nand queries come from the same place, in this case, the output of the previous layer in the\nencoder. Each position in the encoder can attend to all positions in the previous layer of the\nencoder.\n• Similarly, self-attention layers in the decoder allow each position in the decoder to attend to\nall positions in the decoder up to and including that position. We need to prevent leftward',
#   'metadata': {'eventtype': 'Poster',
#    'description-abstract': 'The dominant sequence transduction models are based on complex recurrent orconvolutional neural networks in an encoder and decoder configuration. The best performing such models also connect the encoder and decoder through an attentionm echanisms.  We propose a novel, simple network architecture based solely onan attention mechanism, dispensing with recurrence and convolutions entirely.Experiments on two machine translation tasks show these models to be superiorin quality while being more parallelizable and requiring significantly less timeto train. Our single model with 165 million parameters, achieves 27.5 BLEU onEnglish-to-German translation, improving over the existing best ensemble result by over 1 BLEU. On English-to-French translation, we outperform the previoussingle state-of-the-art with model by 0.7 BLEU, achieving a BLEU score of 41.1.',
#    'title': 'Attention is All you Need',
#    'lastpage': '6008',
#    'creator': 'PyPDF',
#    'published': '2017',
#    'firstpage': '5998',
#    'subject': 'Neural Information Processing Systems http://nips.cc/',
#    'doc_index': 273,
#    'language': 'en-US',
#    'total_pages': 11,
#    'book': 'Advances in Neural Information Processing Systems 30',
#    'publisher': 'Curran Associates, Inc.',
#    'created': '2017',
#    'author': 'Ashish Vaswani, Noam Shazeer, Niki Parmar, Jakob Uszkoreit, Llion Jones, Aidan N. Gomez, Łukasz Kaiser, Illia Polosukhin',
#    'page': 4,
#    'content_length': 493,
#    'producer': 'PyPDF2',
#    'editors': 'I. Guyon and U.V. Luxburg and S. Bengio and H. Wallach and R. Fergus and S. Vishwanathan and R. Garnett',
#    'page_label': '5',
#    'type': 'Conference Proceedings',
#    'moddate': '2018-02-12T21:22:10-08:00',
#    'description': 'Paper accepted and presented at the Neural Information Processing Systems Conference (http://nips.cc/)',
#    'creationdate': '',
#    'date': '2017',
#    'source': 'data/pdfs/research1.pdf'},
#   'distance': 0.8974354863166809,
#   'similarity_score': 0.10256451368331909,
#   'rank': 4}]

# %% [markdown]
# # Integrate RAG with LLM's

# %% [markdown]
# ## Open AI

# %%
API_KEY_OPENAI = "gareeb"

# %%
# !pip install langchain-openai
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-1.6.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: certifi>=2024.6.2 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-openai) (2026.1.4)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-openai) (1.6.0)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-openai) (3.1.0)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.14.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain-openai) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain-openai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain-openai) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain-openai) (0.11.1)
# Requirement already satisfied: packaging>=23.2.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain-openai) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain-openai) (2.12.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain-openai) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.6.0->langchain-openai) (0.17.0)
# Requirement already satisfied: anyio in /Applications/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain-openai) (4.10.0)
# Requirement already satisfied: httpcore==1.* in /Applications/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain-openai) (1.0.9)
# Requirement already satisfied: idna in /Applications/anaconda3/lib/python3.13/site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain-openai) (3.18)
# Requirement already satisfied: h11>=0.16 in /Applications/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Applications/anaconda3/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain-openai) (3.0.0)
# Requirement already satisfied: distro>=1.7.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain-openai) (1.9.0)
# Requirement already satisfied: orjson>=3.9.14 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain-openai) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain-openai) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain-openai) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain-openai) (1.3.0)
# Requirement already satisfied: websockets>=15.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain-openai) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain-openai) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain-openai) (0.24.0)
# Requirement already satisfied: httpx2<3,>=2.7.0 in /Applications/anaconda3/lib/python3.13/site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (2.10.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Applications/anaconda3/lib/python3.13/site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (0.16.0)
# Requirement already satisfied: tqdm>4 in /Applications/anaconda3/lib/python3.13/site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (4.67.1)
# Requirement already satisfied: httpcore2==2.10.0 in /Applications/anaconda3/lib/python3.13/site-packages (from httpx2<3,>=2.7.0->openai<4.0.0,>=2.45.0->langchain-openai) (2.10.0)
# Requirement already satisfied: truststore>=0.10 in /Applications/anaconda3/lib/python3.13/site-packages (from httpx2<3,>=2.7.0->openai<4.0.0,>=2.45.0->langchain-openai) (0.10.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Applications/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.6.0->langchain-openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Applications/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.6.0->langchain-openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Applications/anaconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.6.0->langchain-openai) (0.4.2)
# Requirement already satisfied: regex in /Applications/anaconda3/lib/python3.13/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.7.19)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Applications/anaconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain-openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Applications/anaconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain-openai) (2.5.0)
# Downloading langchain_openai-1.6.0-py3-none-any.whl (125 kB)
# Downloading tiktoken-0.14.0-cp313-cp313-macosx_11_0_arm64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 13.3 MB/s  0:00:00
# Installing collected packages: tiktoken, langchain-openai
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [langchain-openai]
# Successfully installed langchain-openai-1.6.0 tiktoken-0.14.0

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    openai_api_key = API_KEY_OPENAI,
    model = "gpt-5.4",
    temperature=0.1, # low for fact based ans and high for creative ans like poem
    max_tokens = 1024
)

# %%
# generate our retrieval-augmented output
def generate_output(query, retriever, llm, top_k=3):
    results = retriever.retrieve(query, top_k)

    context = "\n".join([doc["document"] for doc in results]) if results else ""

    if not context:
        print("we found no relevant context for the given query")

    # context + query
    prompt = f""" use given context to generate the answer for the query
                Context: {context}
                Query: {query} """

    response = llm.invoke(prompt) # expecting a string as prompt
    return response.content

# %%
answer = generate_output("what is encoder-decoder?", rag_retriever, llm)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# embeddings shape: (1, 384)
# retrieved 3 documents
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# File /Applications/anaconda3/lib/python3.13/site-packages/langchain_openai/chat_models/base.py:1880, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1879 else:
# -> 1880     raw_response = self.client.with_raw_response.create(**payload)
#    1881     response = raw_response.parse()
#
# File /Applications/anaconda3/lib/python3.13/site-packages/openai/_legacy_response.py:369, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     367 kwargs["extra_headers"] = extra_headers
# --> 369 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File /Applications/anaconda3/lib/python3.13/site-packages/openai/_utils/_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File /Applications/anaconda3/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:1296, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1295 validate_response_format(response_format)
# -> 1296 return self._post(
#    1297     "/chat/completions",
#    1298     body=maybe_transform(
#    1299         {
#    1300             "messages": messages,
#    1301             "model": model,
#    1302             "audio": audio,
#    1303             "frequency_penalty": frequency_penalty,
#    1304             "function_call": function_call,
#    1305             "functions": functions,
#    1306             "logit_bias": logit_bias,
#    1307             "logprobs": logprobs,
#    1308             "max_completion_tokens": max_completion_tokens,
#    1309             "max_tokens": max_tokens,
#    1310             "metadata": metadata,
#    1311             "modalities": modalities,
#    1312             "moderation": moderation,
#    1313             "n": n,
#    1314             "parallel_tool_calls": parallel_tool_calls,
#    1315             "prediction": prediction,
#    1316             "presence_penalty": presence_penalty,
#    1317             "prompt_cache_key": prompt_cache_key,
#    1318             "prompt_cache_options": prompt_cache_options,
#    1319             "prompt_cache_retention": prompt_cache_retention,
#    1320             "reasoning_effort": reasoning_effort,
#    1321             "response_format": response_format,
#    1322             "safety_identifier": safety_identifier,
#    1323             "seed": seed,
#    1324             "service_tier": service_tier,
#    1325             "stop": stop,
#    1326             "store": store,
#    1327             "stream": stream,
#    1328             "stream_options": stream_options,
#    1329             "temperature": temperature,
#    1330             "tool_choice": tool_choice,
#    1331             "tools": tools,
#    1332             "top_logprobs": top_logprobs,
#    1333             "top_p": top_p,
#    1334             "user": user,
#    1335             "verbosity": verbosity,
#    1336             "web_search_options": web_search_options,
#    1337         },
#    1338         completion_create_params.CompletionCreateParamsStreaming
#    1339         if stream
#    1340         else completion_create_params.CompletionCreateParamsNonStreaming,
#    1341     ),
#    1342     options=make_request_options(
#    1343         extra_headers=extra_headers,
#    1344         extra_query=extra_query,
#    1345         extra_body=extra_body,
#    1346         timeout=timeout,
#    1347         security={"bearer_auth": True},
#    1348     ),
#    1349     cast_to=ChatCompletion,
#    1350     stream=stream or False,
#    1351     stream_cls=Stream[ChatCompletionChunk],
#    1352 )
#
# File /Applications/anaconda3/lib/python3.13/site-packages/openai/_base_client.py:1382, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1379 opts = FinalRequestOptions.construct(
#    1380     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1381 )
# -> 1382 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File /Applications/anaconda3/lib/python3.13/site-packages/openai/_base_client.py:1155, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1154     log.debug("Re-raising status error")
# -> 1155     raise self._make_status_error_from_response(err.response) from None
#    1157 break
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: gareeb. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}
#
# The above exception was the direct cause of the following exception:
#
# OpenAIAuthenticationError                 Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 answer = generate_output("what is encoder-decoder?", rag_retriever, llm)
#
# Cell In[85], line 15, in generate_output(query, retriever, llm, top_k)
#      10 # context + query
#      11 prompt = f""" use given context to generate the answer for the query
#      12             Context: {context}
#      13             Query: {query} """
# ---> 15 response = llm.invoke(prompt) # expecting a string as prompt
#      16 return response.content
#
# File /Applications/anaconda3/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:477, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     463 @override
#     464 def invoke(
#     465     self,
#    (...)    470     **kwargs: Any,
#     471 ) -> AIMessage:
#     472     config = ensure_config(config)
#     473     return cast(
#     474         "AIMessage",
#     475         cast(
#     476             "ChatGeneration",
# --> 477             self.generate_prompt(
#     478                 [self._convert_input(input)],
#     479                 stop=stop,
#     480                 callbacks=config.get("callbacks"),
#     481                 tags=config.get("tags"),
#     482                 metadata=config.get("metadata"),
#     483                 run_name=config.get("run_name"),
#     484                 run_id=config.pop("run_id", None),
#     485                 **kwargs,
#     486             ).generations[0][0],
#     487         ).message,
#     488     )
#
# File /Applications/anaconda3/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1866, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1857 @override
#    1858 def generate_prompt(
#    1859     self,
#    (...)   1863     **kwargs: Any,
#    1864 ) -> LLMResult:
#    1865     prompt_messages = [p.to_messages() for p in prompts]
# -> 1866     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File /Applications/anaconda3/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1673, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1670 for i, m in enumerate(input_messages):
#    1671     try:
#    1672         results.append(
# -> 1673             self._generate_with_cache(
#    1674                 m,
#    1675                 stop=stop,
#    1676                 run_manager=run_managers[i] if run_managers else None,
#    1677                 **kwargs,
#    1678             )
#    1679         )
#    1680     except BaseException as e:
#    1681         if run_managers:
#
# File /Applications/anaconda3/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:2011, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    2009     result = generate_from_stream(iter(chunks))
#    2010 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 2011     result = self._generate(
#    2012         messages, stop=stop, run_manager=run_manager, **kwargs
#    2013     )
#    2014 else:
#    2015     result = self._generate(messages, stop=stop, **kwargs)
#
# File /Applications/anaconda3/lib/python3.13/site-packages/langchain_openai/chat_models/base.py:1885, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1883     _handle_openai_bad_request(e)
#    1884 except openai.APIError as e:
# -> 1885     _handle_openai_api_error(e)
#    1886 except Exception as e:
#    1887     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File /Applications/anaconda3/lib/python3.13/site-packages/langchain_openai/chat_models/base.py:654, in _handle_openai_api_error(e)
#     650     raise OpenAIAPIContextOverflowError(
#     651         message=e.message, request=e.request, body=e.body
#     652     ) from e
#     653 if isinstance(e, openai.AuthenticationError):
# --> 654     raise OpenAIAuthenticationError(
#     655         message=e.message, response=e.response, body=e.body
#     656     ) from e
#     657 if isinstance(e, openai.PermissionDeniedError):
#     658     raise OpenAIPermissionDeniedError(
#     659         message=e.message, response=e.response, body=e.body
#     660     ) from e
#
# OpenAIAuthenticationError: Error code: 401 - {'error': {'message': 'Incorrect API key provided: gareeb. You can find your API key at https://platform.openai.com/account/api-keys.', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_api_key'}}

# %%
answer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 answer
#
# NameError: name 'answer' is not defined

# %% [markdown]
# ## Groq

# %%
API_Key_GROQ= "grok_api_key"

# %%
# !pip install langchain-groq
# Out:
# Requirement already satisfied: langchain-groq in /Applications/anaconda3/lib/python3.13/site-packages (1.1.3)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-groq) (1.6.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Applications/anaconda3/lib/python3.13/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.10.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Applications/anaconda3/lib/python3.13/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Applications/anaconda3/lib/python3.13/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Applications/anaconda3/lib/python3.13/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.12.4)
# Requirement already satisfied: sniffio in /Applications/anaconda3/lib/python3.13/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.0)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /Applications/anaconda3/lib/python3.13/site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /Applications/anaconda3/lib/python3.13/site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (3.18)
# Requirement already satisfied: certifi in /Applications/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Applications/anaconda3/lib/python3.13/site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Applications/anaconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.11.1)
# Requirement already satisfied: packaging>=23.2.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Applications/anaconda3/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.32.5)
# Requirement already satisfied: websockets>=15.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (16.1.1)
# Requirement already satisfied: xxhash>=3.0.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /Applications/anaconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Applications/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Applications/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Applications/anaconda3/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Applications/anaconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Applications/anaconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.5.0)

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    groq_api_key=API_Key_GROQ,
    model="qwen/qwen3.6-27b",
    temperature=0.1,
    max_tokens=1024
)

# %%
# generate our retrieval-augmented output
def generate_output(query, retriever, llm, top_k=3):
    results = retriever.retrieve(query, top_k)

    context = "\n".join([doc["document"] for doc in results]) if results else ""

    if not context:
        print("we found no relevant context for the given query")

    # context + query
    prompt = f""" use given context to generate the answer for the query
                Context: {context}
                Query: {query} """

    response = llm.invoke([prompt.format(context=context, query=query)]) # expecting a list as prompt
    return response.content

# %%
answer = generate_output("what is RAG?", rag_retriever, llm)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# embeddings shape: (1, 384)
# retrieved 3 documents

# %%
# from groq import Groq

# client = Groq(api_key=API_Key_GROQ)

# models = client.models.list()

# for model in models.data:
#     print(model.id)

# 🌟🌟🌟🌟to see what models you can use with this API key

# %%
print(answer)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Analyze User Input:**
#    - **Context:** The provided text is repetitive and fragmented. It mentions: "and speculate on upcoming trends and innovations. Our contributions are as follows: • In this survey, we present a thorough and systematic review of the state-of-the-art RAG methods, delineating its evolution through paradigms including naive RAG, arXiv:2312.10997v5 [cs.CL] 27 Mar 2024" (repeated 3 times).
#    - **Query:** "what is RAG?"
#    - **Task:** Use the given context to generate an answer for the query.
#
# 2.  **Evaluate Context vs. Query:**
#    - The context mentions "RAG methods" and "naive RAG" as part of a survey on state-of-the-art methods. It also mentions an arXiv ID (2312.10997v5) and a date.
#    - However, the context *does not define* what RAG stands for or what it is. It only refers to it as a set of methods/paradigms being reviewed.
#    - I need to answer based *only* on the provided context, but I should also acknowledge the limitation if the context doesn't contain the answer. Alternatively, I can infer from common knowledge that RAG stands for Retrieval-Augmented Generation, but the prompt says "use given context to generate the answer". I must stick closely to the context.
#
# 3.  **Formulate Response (Internal Refinement):**
#    - The provided context does not explicitly define what RAG is. It only mentions that the survey reviews "state-of-the-art RAG methods" and traces their evolution through paradigms like "naive RAG."
#    - I should state clearly that the context doesn't provide a definition, but based on the context, RAG refers to a set of methods/paradigms in AI/machine learning that are being systematically reviewed, with "naive RAG" being one of its evolutionary stages.
#    - I can also politely note that while the context doesn't define it, RAG commonly stands for Retrieval-Augmented Generation in AI literature, but I'll keep the focus on what the context actually says.
#
#    Draft: Based on the provided context, RAG is not explicitly defined. The text only mentions that it refers to a set of methods whose evolution is reviewed in the survey, with "naive RAG" cited as one of its paradigms. The context focuses on presenting a systematic review of state-of-the-art RAG methods and speculating on future trends, but does not provide a direct definition of what RAG stands for or how it works.
#
# 4.  **Check Constraints:**
#    - "use given context to generate the answer for the query"
#    - The context is repetitive and lacks a definition.
#    - I must be honest about the context's limitations while directly answering based on it.
#    - I'll keep it concise and strictly tied to the provided text.
#
#    Final polish: Based on the provided context, RAG is not explicitly defined. The text only indicates that it refers to a family of methods whose evolution is systematically reviewed in the survey, with "naive RAG" mentioned as one of its foundational paradigms. The context focuses on analyzing state-of-the-art RAG methods and forecasting future trends, but does not provide a direct definition or explanation of what RAG stands for or how it functions. If you need a technical definition, RAG typically stands for Retrieval-Augmented Generation in AI research, though this is outside the provided text.
#
#    This meets the requirement, stays faithful to the context, and handles the missing information appropriately. I'll output this.✅
# </think>
#
# Based on the provided context, **RAG is not explicitly defined**. The text only indicates that it refers to a set of methods whose evolution is systematically reviewed in the survey, with `"naive RAG"` cited as one of its foundational paradigms. The context focuses on presenting a thorough review of state-of-the-art RAG methods and speculating on future trends, but does not provide a direct definition or explanation of what RAG stands for or how it works.
#
# *(Note: In AI research, RAG commonly stands for **Retrieval-Augmented Generation**, a technique that combines large language models with external knowledge retrieval to improve response accuracy, though this definition falls outside the provided context.)*

# %% [markdown]
#  ## Claude

# %%
# do it on your own

# %%
# !pip install langchain-anthropic
