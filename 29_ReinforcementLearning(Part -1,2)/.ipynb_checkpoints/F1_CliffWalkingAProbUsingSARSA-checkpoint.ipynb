# %%
# !pip install gymnasium
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 31.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [gymnasium]/2 [gymnasium]
# ...

# %%
# !pip install "gymnasium[toy-text]"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 2.9 MB/s  0:00:05 eta 0:00:01
# ...

# %%
import gymnasium as gym
import numpy as np
import random

# %%
# sam enviroment
env = gym.make("CliffWalking-v1")

# %%
print(env.observation_space.n) #states
print(env.action_space.n) # actions

starting_state,_ = env.reset() #36 = 3*12 + 0
print(starting_state) #36
# Out:
# 48
# 4
# 36

# %% [markdown]
# # SARSA

# %%
gamma  = 0.99
alpha  = 0.5
episodes = 500
epsilon = 0.1

# %%
# Q table => store values
Q = np.zeros((48, 4))

# %%
#Policy - epsilon-greedy : state -> action
def epsilon_greedy(state):
    if random.random() < epsilon: ## explore case
        return env.action_space.sample() # radome actions => EXPLORE
    else:
        return np.argmax(Q[state])  # exploit case

# %%
for episode in range(episodes):
    # lets see the training path also
    render = (episode% 50  == 0)

    if render: # this if section we have added to visually see the rendering process
        env = gym.make("CliffWalking-v1", render_mode = "human")
        print(f"rendering env for episode={episode+1}/500")
    else:
        env  = gym.make("CliffWalking-v1")

    done = False # when the episodes has ended ( either reached the end or truncate( matlab we dont want to leave it for infinite so we have set time limit)
    state,_ = env.reset()
    action = epsilon_greedy(state) # as SARSA is on-policy algo. , the policy will tell what action to take.

    total_reward = 0
    episode_len = 0

    while not done:
        next_state , reward , terminated, truncated , _ = env.step(action)
        done = terminated or truncated
        next_action = epsilon_greedy(next_state)

        # SARSA update
        Q[state, action] += alpha * (reward + gamma*(Q[next_state , next_action]- Q[state, action] ))

        state = next_state
        action = next_action

        total_reward += reward
        episode_len += 1
        
    print(f"episode = {episode+1}/500:  total reward = {total_reward} & ep length = {episode_len}")
    env.close()
# Out:
# rendering env for episode=1/500
# episode = 1/500:  total reward = -137 & ep length = 137
# episode = 2/500:  total reward = -2818 & ep length = 739
# episode = 3/500:  total reward = -65 & ep length = 65
# episode = 4/500:  total reward = -55 & ep length = 55
# episode = 5/500:  total reward = -248 & ep length = 149
# episode = 6/500:  total reward = -218 & ep length = 119
# episode = 7/500:  total reward = -58 & ep length = 58
# episode = 8/500:  total reward = -39 & ep length = 39
# episode = 9/500:  total reward = -179 & ep length = 80
# episode = 10/500:  total reward = -45 & ep length = 45
# episode = 11/500:  total reward = -167 & ep length = 68
# episode = 12/500:  total reward = -79 & ep length = 79
# episode = 13/500:  total reward = -45 & ep length = 45
# episode = 14/500:  total reward = -62 & ep length = 62
# episode = 15/500:  total reward = -66 & ep length = 66
# episode = 16/500:  total reward = -27 & ep length = 27
# ...

# %%
 # so after training , what did our agent learn ?? lets see visually

env =gym.make("CliffWalking-v1", render_mode="human")
state,_= env.reset()
done = False
total_reward = 0
episode_len = 0

while not done:
    action = np.argmax(Q[state])
    state, reward , terminated , truncated,_= env.step(action)
    done = terminated or truncated

    total_reward += reward
    episode_len += 1

print(f"total reward = {total_reward} & episode len = {episode_len}")
env.close()
# Out:
# total reward = -17 & episode len = 17
